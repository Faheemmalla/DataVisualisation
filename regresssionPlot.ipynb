# %% [markdown]
# <a href="https://colab.research.google.com/github/Faheemmalla/DataVisualisation/blob/main/regresssionPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# lmplot()

# %%
tips = sns.load_dataset("tips")

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips)

# %%
#Linear line hataani ho
sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips,hue='sex')

# %% [markdown]
# #Polynomial regression

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, order=2)
#Ye curved line bana dega (degree 2).
